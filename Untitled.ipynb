# %%
import os
from dotenv import load_dotenv
from autogonai.core import Client
load_dotenv()
# Set your API key before making the request
client = Client(api_key=os.environ['AUTOGON_API_KEY'])

client.Projects.create(
    name="juvamed",
    description="This is a great project started to develop and AI Doctor that can make diagnoses from medical images"
)
# Out:
# {'id': 1043,
#  'app_id': 'd5cb5085-d729-40d1-be1e-096e3bf8328c',
#  'project_name': 'juvamed',
#  'project_description': 'This is a great project started to develop and AI Doctor that can make diagnoses from medical images',
#  'project_data': None,
#  'project_compiled_models': None,
#  'project_compiled_weights': None,
#  'isDeleted': False,
#  'is_public': False,
#  'ref_project': None,
#  'updated_at': '2024-02-14T21:17:44.557833Z',
#  'created_at': '2024-02-14T21:17:44.557880Z'}

# %%
X_AUG_KEY: os.environ['AUTOGON_API_KEY']

# %%
gpt4_url = f"https://api.autogon.ai/api/v1/services/chatbot/{agent_id}/chat/"
payload = json.dumps({

# %%
import requests
import json
agent_id = "535f968f-e0b0-45ae-9156-f5a6469c226e"
url = f"https://api.autogon.ai/api/v1/services/chatbot/{agent_id}/chat/"

payload = json.dumps({
  "session_id": "test-session-id-1497505decbe",
  "question": "Hello Chatbot"
})
headers = {
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"message":"An error occurred: 400 Client Error: Bad Request for url: https://chatbotapi.autogon.ai/api/v1/chatbot-service/chat/"}

# %%
import requests

# %%
res = requests.post(url=gpt4_url, json=params)

# %%
res.status_code
# Out:
# 200

# %%
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="UTF-8" />
#
#     <link
#       rel="icon"
#       type="image/svg+xml"
#       href="https://cloud-autogonai.s3.us-east-2.amazonaws.com/MicrosoftTeams-image+(7).png"
#     />
#
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <!-- FONTS -->
#     <link rel="preconnect" href="https://fonts.googleapis.com" />
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin />
#     <link
#       href="https://fonts.googleapis.com/css2?family=Inter&family=Roboto+Condensed:wght@300;400;700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       href="https://fonts.googleapis.com/css2?family=Poppins:wght@400;500;600;700&display=swap"
#       rel="stylesheet"
#     />
#     <link
#       href="https://fonts.googleapis.com/css2?family=Rowdies:wght@300&family=Tilt+Warp&display=swap"
#       rel="stylesheet"
#     />
#     <link
# ...
